# %%
import pandas as pd
data = pd.read_csv('/Users/suso/BootcampDA/Unit4/Labs/lab-random-variable-distributions/files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv')

# %%
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
#1. Get the numerical variables from our dataset.

numerical_data = data.select_dtypes(include=['float64', 'int64'])

# %%
numerical_data
# Out:
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
#2. Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.

import seaborn as sns
import matplotlib.pyplot as plt

#For normal distribution
for column in numerical_data.columns:
    sns.distplot(numerical_data[column])
    plt.title(f'Distribution of {column}')
    plt.show()
# Out:
# /var/folders/5y/_5l3y2p900scjg2bd7r52_lh0000gn/T/ipykernel_4936/15705434.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numerical_data[column])
# /var/folders/5y/_5l3y2p900scjg2bd7r52_lh0000gn/T/ipykernel_4936/15705434.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#For exponential distribution
for column in numerical_data.columns:
    plt.hist(numerical_data[column], bins=20, density=True)
    plt.title(f'Histogram of {column}')
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.show()

# %%
#3. Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Log-transformed distribution plots
for column in numerical_data.columns:
    transformed_data = np.log(numerical_data[column])
    sns.distplot(transformed_data)
    plt.title(f'Log-Transformed Distribution of {column}')
    plt.show()
# Out:
# /var/folders/5y/_5l3y2p900scjg2bd7r52_lh0000gn/T/ipykernel_4936/2205276795.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(transformed_data)
# /Users/suso/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /var/folders/5y/_5l3y2p900scjg2bd7r52_lh0000gn/T/ipykernel_4936/2205276795.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# ...
